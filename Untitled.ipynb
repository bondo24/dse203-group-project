# %% [markdown]
# ### Chosen company:

# %% [markdown]
# access ______'s wiki page, data scrape for competitors:

# %%
import pandas as pd

# %%
company_url = 'https://en.wikipedia.org/wiki/List_of_mergers_and_acquisitions_by_Microsoft'
table_attributes = {'class': 'wikitable'}

pd.read_html(company_url, attrs=table_attributes)[0]
# Out:
#           0                                      1               2  \
# 0    Number                                Company         Country
# 1         1                      Forethought, Inc.   United States
# 2         2                     Consumers Software          Canada
# 3         3                           Fox Software   United States
# 4         4                              SOFTIMAGE          Canada
# 5         5                      Altamira Software   United States
# 6         6                               NextBase  United Kingdom
# 7         7                      One Tree Software   United States
# 8         8                         RenderMorphics   United States
# 9         9                       Network Managers  United Kingdom
# 10       10             The Blue Ribbon SoundWorks   United States
# 11       11                                Netwise   United States
# 12       12             Bruce Artwick Organization   United States
# ...

# %% [markdown]
# randomly choose 3 entries from competitors

# %% [markdown]
# access ______'s wiki page, data scrape for acquisitions

# %% [markdown]
# randomly choose 3 entries from acquisitions

# %% [markdown]
# load company into neo4j
